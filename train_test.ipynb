# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import datetime 
import matplotlib.pyplot as plt
import matplotlib
from sklearn.preprocessing import MinMaxScaler

# %%
path="/content/drive/MyDrive/train.csv"
train_data = pd.read_csv(path,index_col='ID') #ID轉換成index
train_data
# Out:
#       Administrative  Administrative_Duration  Informational  \
# ID
# 8773               0                 0.000000              0
# 6709               0                 0.000000              0
# 1463               9               301.000000              0
# 4095               2                13.333333              0
# 3346               0                 0.000000              0
# ...              ...                      ...            ...
# 3758               0                 0.000000              0
# 4437               1                15.200000              2
# 7449               0                 0.000000              0
# 665                9               183.785714              1
# 552                3                49.750000              0
#
#       Informational_Duration  ProductRelated  ProductRelated_Duration  \
# ID
# 8773                     0.0               1                 0.000000
# 6709                     0.0               1                 0.000000
# ...

# %%
print(len(train_data))  #資料數量
# Out:
# 8100

# %%
train_data.columns = ["Administrative","Administrative_Duration","Informational","Informational_Duration","ProductRelated","ProductRelated_Duration","BounceRates","ExitRates","PageValues","SpecialDay","Month","OperatingSystems","Browser","Region","TrafficType","VisitorType","Weekend","Revenue"]
train_data     #dataframe
# Out:
#       Administrative  Administrative_Duration  Informational  \
# ID
# 8773               0                 0.000000              0
# 6709               0                 0.000000              0
# 1463               9               301.000000              0
# 4095               2                13.333333              0
# 3346               0                 0.000000              0
# ...              ...                      ...            ...
# 3758               0                 0.000000              0
# 4437               1                15.200000              2
# 7449               0                 0.000000              0
# 665                9               183.785714              1
# 552                3                49.750000              0
#
#       Informational_Duration  ProductRelated  ProductRelated_Duration  \
# ID
# 8773                     0.0               1                 0.000000
# 6709                     0.0               1                 0.000000
# ...

# %%
# train_periods = 30                               
# test_periods = 8                             
# train_data = train_data[:-test_periods]
# test_data = train_data[-test_periods:]                 

# scaler = MinMaxScaler().fit(train_data)                          
# train_scaled = scaler.transform(train_data)        #標準化             
# train_scaled = torch.FloatTensor(train_scaled)                     
# train_scaled = train_scaled.reshape(-1)

# def get_x_y_pairs(train_scaled, train_periods, test_periods):             
#   x_train = [train_data[i:i+train_periods]
#               for i in range(len(train_data)-train_periods-test_periods+1)]
#   y_train = [train_data[i+train_periods:i+train_periods+test_periods]
#               for i in range(len(train_data)-train_periods-test_periods+1)]
#   return x_train, y_train

# x_train, y_train = get_x_y_pairs(train_data, train_periods, test_periods)

# %%
# print(x_train[0])
# print(y_train[0])

# %%
# class LSTM(nn.Module):                            #LSTM               
#   def __init__(self, input_size, hidden_size, output_size):
#     super(LSTM, self).__init__()
#     self.hidden_size = hidden_size
#     self.lstm = nn.LSTM(input_size, hidden_size)
#     self.linear = nn.Linear(hidden_size, output_size)
        
#   def forward(self, x):
#     self.hidden = (torch.zeros(1,1,self.hidden_size), torch.zeros(1,1,self.hidden_size))
#     lstm_out, self.hidden = self.lstm(x.values.reshape(len(x),1,-1), self.hidden) 
#     predictions = self.linear(lstm_out.values.reshape(len(x), -1))   
#     return predictions[-1]

# model = LSTM(input_size=1, hidden_size=100, output_size=test_periods)     
# model = model
# criterion = nn.MSELoss()                        #優化器(optimizer)
# optimizer = optim.Adam(model.parameters(), lr=0.001)        #損失函數(loss function)

# %%
# scaler = MinMaxScaler()    #標準化
# norm_train_data = pd.DataFrame(scaler.fit_transform(train_data),columns=train_data.columns,index=train_data.index)
# norm_train_data
# Out:
#       Administrative  Administrative_Duration  Informational  \
# ID
# 8773        0.000000                 0.000000       0.000000
# 6709        0.000000                 0.000000       0.000000
# 1463        0.333333                 0.088562       0.000000
# 4095        0.074074                 0.003923       0.000000
# 3346        0.000000                 0.000000       0.000000
# ...              ...                      ...            ...
# 76          0.259259                 0.038789       0.000000
# 1783        0.000000                 0.000000       0.000000
# 6989        0.222222                 0.021037       0.000000
# 3237        0.000000                 0.000000       0.000000
# 4215        0.407407                 0.177654       0.083333
#
#       Informational_Duration  ProductRelated  ProductRelated_Duration  \
# ID
# 8773                0.000000        0.001418             0.000000e+00
# 6709                0.000000        0.001418             0.000000e+00
# ...

# %%
import tqdm                     
n = 30
feature_names = list(train_data.drop('Revenue',axis=1).columns)
x = []
y = []
indexes = []
train_data_x = train_data[feature_names]
for i in tqdm.tqdm_notebook(range(0,len(train_data)-n)):
  x.append(train_data_x.iloc[i:i+n].values)
  y.append(train_data['Revenue'].iloc[i+n-1])
  indexes.append(train_data.index[i+n-1])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/8062 [00:00<?, ?it/s]

# %%
print(x_train[0])
print(y_train[0])

# %%
x = np.array(x_train)
y = np.array(y_train)
print(x.shape)
print(y.shape)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from sklearn.metrics import roc_auc_score
import keras.backend as K

# %%
n_steps = 30
n_features = 18

dependencies = {'auc_roc': roc_auc_score}
def precision(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision
def recall(y_true, y_pred): 
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

model = Sequential()
model.add(LSTM(50,activation='relu',return_sequences=False,input_shape = (n_steps,n_features)))
model.add(Dense(1))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy', precision, recall])
model.fit(x=x, y=y, batch_size=8, epochs=15)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-f62f83cde223> in <module>
#      15
#      16 model = Sequential()
# ---> 17 model.add(LSTM(50,activation='relu',return_sequences=False,input_shape = (n_steps,n_features)))
#      18 model.add(Dense(1))
#      19 model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy', precision, recall])
#
# TypeError: __init__() got an unexpected keyword argument 'activation'

# %%
x_train = x[0:7942]
y_train = y[0:7942]
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy', precision, recall])

history = model.fit(x_train,y_train,batch_size=50,epochs=20)
# Out:
# Epoch 1/20
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-773caaafb4e1> in <module>
#       2 y_train = y[0:150]
#       3 model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy', precision, recall])
# ----> 4 history = model.fit(x_train,y_train,batch_size=50,epochs=20)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py in autograph_handler(*args, **kwargs)
#    1145           except Exception as e:  # pylint:disable=broad-except
# ...

# %%
# import tensorflow as tf
# from keras.models import Input, Model
# from sklearn import datasets
# print(f"TF version: {tf.__version__}, Keras version: {keras.__version__}\n")
# # dummy dataset
# iris = datasets.load_iris()
# x, y_ = iris.data, iris.target
# def one_hot(v): return np.eye(len(np.unique(v)))[v]
# y = one_hot(y_)
# # model
# inp = Input(shape=(4,))
# dense = Dense(8, activation='relu')(inp)
# dense = Dense(16, activation='relu')(dense)
# dense = Dense(3, activation='softmax')(dense)
# model = Model(inputs=inp, outputs=dense)

# def precision(y_true, y_pred): 
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
#     precision = true_positives / (predicted_positives + K.epsilon())
#     return precision
# def recall(y_true, y_pred): 
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     recall = true_positives / (possible_positives + K.epsilon())
#     return recall

# model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy', precision, recall])
# model.fit(x=x, y=y, batch_size=8, epochs=15)
# Out:
# TF version: 2.8.2, Keras version: 2.8.0
#
# Epoch 1/15
# 19/19 [==============================] - 0s 1ms/step - loss: 1.9782 - accuracy: 0.3333 - precision: 0.3377 - recall: 0.3377
# Epoch 2/15
# 19/19 [==============================] - 0s 1ms/step - loss: 1.2336 - accuracy: 0.3333 - precision: 0.3712 - recall: 0.3136
# Epoch 3/15
# 19/19 [==============================] - 0s 1ms/step - loss: 0.9515 - accuracy: 0.5067 - precision: 0.5000 - recall: 0.1338
# Epoch 4/15
# 19/19 [==============================] - 0s 1ms/step - loss: 0.8930 - accuracy: 0.6533 - precision: 0.8649 - recall: 0.2500
# Epoch 5/15
# 19/19 [==============================] - 0s 1ms/step - loss: 0.8451 - accuracy: 0.7333 - precision: 0.8772 - recall: 0.2456
# Epoch 6/15
# 19/19 [==============================] - 0s 1ms/step - loss: 0.8057 - accuracy: 0.7667 - precision: 0.7675 - recall: 0.2412
# Epoch 7/15
# ...
